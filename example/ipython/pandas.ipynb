# %%
import pandas as pd

# %%
ls
# Out:
# CSV.ipynb         LIST.ipynb        grades.csv        grades_short.csv  pandas.ipynb

# %%
mydata = pd.read_csv("grades.csv")

# %%
mydata.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13
#
# [5 rows x 6 columns]

# %%
mydata
# Out:
#      姓名  國文  英文  數學  自然  社會
# 0   劉俊安   9  10  15  10  13
# 1   胡玉華  10  10  10   8   9
# 2   黃淑婷  13  15   8  11  14
# 3   陳上紫  10  10   8   9  14
# 4   崔靜成  13  12  14  12  13
# 5   張雅岳  13  12  12  12   8
# 6   梁俊翔  11  13  10  10  14
# 7   林金鳳   8   9  10  10   8
# 8   許協旺   9   9  12  10  10
# 9   郭雅惠  10  15  12  11   9
# 10  張志偉  14   9   8  10  12
# 11  周皇樺  13   9  13  14  15
# 12  李正偉  11  15  11  14  15
# 13  黃旭忠  15  14   9  12  10
# 14  葉雅琳   8  13  10  13  14
# 15  黃淑慧  11   8  10  12  15
# 16  吳芝菁  14   9  11  10   9
# 17  聶珮君  12  11  13  12   9
# 18  梁慧君   9   8   8   8  12
# 19  葉曉玲  14   9  11  15   9
# 20  陳智超  13   9  13  14  13
# 21  黃奕霞   9   8  11  13   8
# 22  沈昆純  12  14  10   9   9
# 23  許惠雯  10  13  12  14  10
# 24  陳竹伯  10  12  15  10  14
# 25  蔡亦瑄  13  13  14  13  12
# 26  戴喜寶  13  11   9  14   9
# 27  馮白屏   8  13  14   8  10
# 28  王金鳳  15  14   8  12   8
# 29  闕進綠  14  11  13   8  11
# 30  連瑋玲   8  10  14   8  13
# 31  林秀娟  15  12   9   9  15
# ...

# %%
mydata["國文"]
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
# 5     13
# 6     11
# 7      8
# 8      9
# 9     10
# 10    14
# 11    13
# 12    11
# 13    15
# 14     8
# ...
# 85    10
# 86    11
# 87    10
# 88    11
# 89    13
# 90     8
# 91    14
# 92     8
# 93    11
# 94    10
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %%
mydata["姓名"]
# Out:
# 0     劉俊安
# 1     胡玉華
# 2     黃淑婷
# 3     陳上紫
# 4     崔靜成
# 5     張雅岳
# 6     梁俊翔
# 7     林金鳳
# 8     許協旺
# 9     郭雅惠
# 10    張志偉
# 11    周皇樺
# 12    李正偉
# 13    黃旭忠
# 14    葉雅琳
# ...
# 85    張雅彬
# 86    林貞儀
# 87    趙偉希
# 88    戴青英
# 89    郭順誠
# 90    胡勝傑
# 91    陳登翰
# 92    蔡淑孝
# 93    李曼夢
# 94    林與忠
# 95    蔡佳燕
# 96    吳筱婷
# 97    陳家銘
# 98    李明威
# 99    農揚勇
# Name: 姓名, Length: 100, dtype: object

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mydata["國文"].plot()

# %%
mydata["國文"].hist()

# %% [markdown]
# 可參考 http://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
# 隨機產生100個70到100的亂數
pgrade = pd.Series(randint(70,100,100))

# %%
pgrade.head()
# Out:
# 0    78
# 1    81
# 2    94
# 3    90
# 4    75
# dtype: int64

# %%
mydata["書審"] = pgrade

# %%
mydata.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  書審
# 0  劉俊安   9  10  15  10  13  78
# 1  胡玉華  10  10  10   8   9  81
# 2  黃淑婷  13  15   8  11  14  94
# 3  陳上紫  10  10   8   9  14  90
# 4  崔靜成  13  12  14  12  13  75
#
# [5 rows x 7 columns]

# %%
mydata["結果"] = " 不錄取"

# %%
mydata.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  書審    結果
# 0  劉俊安   9  10  15  10  13  78   不錄取
# 1  胡玉華  10  10  10   8   9  81   不錄取
# 2  黃淑婷  13  15   8  11  14  94   不錄取
# 3  陳上紫  10  10   8   9  14  90   不錄取
# 4  崔靜成  13  12  14  12  13  75   不錄取
#
# [5 rows x 8 columns]

# %%
select = mydata[["姓名", "國文", "英文", "數學"]]

# %%
select.head()
# Out:
#     姓名  國文  英文  數學
# 0  劉俊安   9  10  15
# 1  胡玉華  10  10  10
# 2  黃淑婷  13  15   8
# 3  陳上紫  10  10   8
# 4  崔靜成  13  12  14
#
# [5 rows x 4 columns]

# %%
mydata[1:4]
# Out:
#     姓名  國文  英文  數學  自然  社會  書審    結果
# 1  胡玉華  10  10  10   8   9  81   不錄取
# 2  黃淑婷  13  15   8  11  14  94   不錄取
# 3  陳上紫  10  10   8   9  14  90   不錄取
#
# [3 rows x 8 columns]

# %%
dir(mydata)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
# ...

# %%
help(mydata.ix)
# Out:
# Help on _IXIndexer in module pandas.core.indexing object:
#
# class _IXIndexer(_NDFrameIndexer)
#  |  A primarily location based indexer, with integer fallback
#  |
#  |  Method resolution order:
#  |      _IXIndexer
#  |      _NDFrameIndexer
#  |      __builtin__.object
#  |
#  |  Methods inherited from _NDFrameIndexer:
#  |
#  |  __call__(self, *args, **kwargs)
#  |
#  |  __getitem__(self, key)
#  |
#  |  __init__(self, obj, name)
#  |
#  |  __iter__(self)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _NDFrameIndexer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
mydata.ix[37]
# Out:
# 姓名     曾怡君
# 國文      11
# 英文      12
# 數學      15
# 自然      13
# 社會      14
# 書審      90
# 結果     不錄取
# Name: 37, dtype: object

# %%
mydata["數學"]==15
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 85     True
# 86    False
# 87    False
# 88    False
# 89    False
# 90     True
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: 數學, Length: 100, dtype: bool

# %%
mydata[mydata["數學"] == 15]
# Out:
#      姓名  國文  英文  數學  自然  社會  書審    結果
# 0   劉俊安   9  10  15  10  13  78   不錄取
# 24  陳竹伯  10  12  15  10  14  87   不錄取
# 36  詹威德  12  13  15  10  14  76   不錄取
# 37  曾怡君  11  12  15  13  14  90   不錄取
# 39  段冠廷   9   8  15  12  15  70   不錄取
# 59  芮秋辛  11  10  15  10   8  87   不錄取
# 67  林哲法  14   9  15  10  14  94   不錄取
# 70  葉儀依   9  13  15   8  14  71   不錄取
# 73  吳志遠  13  15  15   8   8  93   不錄取
# 76  周育霖   9  12  15  13  12  78   不錄取
# 83  李士賢  10  14  15  13  13  96   不錄取
# 85  張雅彬  10  11  15  12   8  87   不錄取
# 90  胡勝傑   8  11  15  10  15  81   不錄取
#
# [13 rows x 8 columns]

# %%
mydata[ (mydata["數學"] == 15) & (mydata["英文"]>12) ]
# Out:
#      姓名  國文  英文  數學  自然  社會  書審    結果
# 36  詹威德  12  13  15  10  14  76   不錄取
# 70  葉儀依   9  13  15   8  14  71   不錄取
# 73  吳志遠  13  15  15   8   8  93   不錄取
# 83  李士賢  10  14  15  13  13  96   不錄取
#
# [4 rows x 8 columns]

# %%
help(mydata.loc)
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  purely label based location based indexing
#  |
#  |  Method resolution order:
#  |      _LocIndexer
#  |      _LocationIndexer
#  |      _NDFrameIndexer
#  |      __builtin__.object
#  |
#  |  Methods inherited from _LocationIndexer:
#  |
#  |  __getitem__(self, key)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _NDFrameIndexer:
#  |
#  |  __call__(self, *args, **kwargs)
#  |
#  |  __init__(self, obj, name)
#  |
#  |  __iter__(self)
#  |
#  |  __setitem__(self, key, value)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _NDFrameIndexer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
mydata.loc[ (mydata["數學"] == 15) & (mydata["英文"]>12) ]
# Out:
#      姓名  國文  英文  數學  自然  社會  書審    結果
# 36  詹威德  12  13  15  10  14  76   不錄取
# 70  葉儀依   9  13  15   8  14  71   不錄取
# 73  吳志遠  13  15  15   8   8  93   不錄取
# 83  李士賢  10  14  15  13  13  96   不錄取
#
# [4 rows x 8 columns]

# %%
mydata.mean()
# Out:
# 國文    11.39
# 英文    11.38
# 數學    11.57
# 自然    11.03
# 社會    11.83
# 書審    84.55
# dtype: float64

# %%
mydata.std()
# Out:
# 國文    2.196853
# 英文    2.273164
# 數學    2.310516
# 自然    2.217720
# 社會    2.486550
# 書審    8.999860
# dtype: float64

# %%
mydata.describe()
# Out:
#                國文          英文          數學         自然         社會         書審
# count  100.000000  100.000000  100.000000  100.00000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000   84.55000
# std      2.196853    2.273164    2.310516    2.21772    2.48655    8.99986
# min      8.000000    8.000000    8.000000    8.00000    8.00000   70.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000   77.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000   84.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000   93.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000   99.00000
#
# [8 rows x 6 columns]

# %%
mydata.corr()
# Out:
#           國文        英文        數學        自然        社會        書審
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421  0.142309
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512  0.176808
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651  0.082409
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594  0.080138
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000 -0.022410
# 書審  0.142309  0.176808  0.082409  0.080138 -0.022410  1.000000
#
# [6 rows x 6 columns]
